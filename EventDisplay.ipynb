# %%
import plotly
import plotly.graph_objs as go
import plotly.express as px
import pprint
import json

from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_3222836/2841742780.py:7: DeprecationWarning:
#
# Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display

# %%
f = open("data/CMSSW_12_2_0_pre2_geom.txt")

# %%
j = json.load(f)

# %%
size=800

# %%
zs=[]
xs=[]
ys=[]
for detid in j:
    z_=[j[detid][0][0], j[detid][1][0], j[detid][2][0], j[detid][3][0], j[detid][0][0], None]
    x_=[j[detid][0][1], j[detid][1][1], j[detid][2][1], j[detid][3][1], j[detid][0][1], None]
    y_=[j[detid][0][2], j[detid][1][2], j[detid][2][2], j[detid][3][2], j[detid][0][2], None]
    zs += z_
    xs += x_
    ys += y_

# %%
zs
# Out:
# [40.07656266158255,
#  33.89483980127424,
#  41.75526615601745,
#  47.93698901632576,
#  40.07656266158255,
#  None,
#  -19.046823134376865,
#  -17.607594428427554,
#  -8.030826553623136,
#  -9.470055259572447,
#  -19.046823134376865,
#  None,
#  -58.661831970749844,
#  -58.661831970749844,
#  -63.65641828225016,
#  -63.65641828225016,
#  -58.661831970749844,
#  None,
#  -3.642971499484335,
#  -3.642971499484335,
#  -13.590908816715665,
#  -13.590908816715665,
#  -3.642971499484335,
#  None,
#  57.560294888867055,
#  50.09933026248958,
#  56.757708957332945,
#  64.21867358371043,
#  57.560294888867055,
#  None,
#  -25.75033062282441,
#  -22.21478653045072,
#  -29.28583396937559,
#  -32.82137806174928,
#  -25.75033062282441,
#  None,
#  17.418359716256536,
#  15.506506152637836,
#  24.746596184943467,
#  26.658449748562166,
#  17.418359716256536,
#  None,
#  -3.7728273770096905,
#  -3.7728273770096905,
#  -13.719415731090308,
#  -13.719415731090308,
#  -3.7728273770096905,
#  None,
# ...

# %%
mods = go.Scatter3d(x=xs,
                    y=ys,
                    z=zs,
                    mode="lines",
                    line=dict(
                        color="rgb(0,255,255,0.5)",
                        ),
                    hoverinfo='text',
                   )

# %%
fig = go.Figure([mods])

# %%
fig.update_layout(
    template="plotly_dark",
    paper_bgcolor="rgb(0,0,0,1)",
    scene = dict(
        xaxis = dict(nticks=10, range=[-300,300],),
        yaxis = dict(nticks=10, range=[-300,300],),
        zaxis = dict(nticks=10, range=[-300,300],),
        aspectratio=dict(x=1, y=1, z=1),
    ),
    width=size,
    height=size,
    margin=dict(r=20, l=10, b=10, t=10));

# %%
fig.write_html("module.html")

# %%
f = uproot.open("/home/users/phchang/work/lst/outputs/PU200_nevt1_idx4.root:tree")

# %%
sim_pt = f["sim_pt"].array(library="pd")[0];
sim_eta = f["sim_eta"].array(library="pd")[0];
sim_phi = f["sim_phi"].array(library="pd")[0];
sim_vx = f["sim_vx"].array(library="pd")[0];
sim_vy = f["sim_vy"].array(library="pd")[0];
sim_vz = f["sim_vz"].array(library="pd")[0];
sim_q = f["sim_q"].array(library="pd")[0];
sim_denom = f["sim_denom"].array(library="pd")[0];
sim_TC_matched = f["sim_TC_matched"].array(library="pd")[0];

# %%
x1 = list(f["T2_x1"].array(library="pd")[0]);
x2 = list(f["T2_x2"].array(library="pd")[0]);
y1 = list(f["T2_y1"].array(library="pd")[0]);
y2 = list(f["T2_y2"].array(library="pd")[0]);
z1 = list(f["T2_z1"].array(library="pd")[0]);
z2 = list(f["T2_z2"].array(library="pd")[0]);

good_x1 = list(f["good_T2_x1"].array(library="pd")[0]);
good_x2 = list(f["good_T2_x2"].array(library="pd")[0]);
good_y1 = list(f["good_T2_y1"].array(library="pd")[0]);
good_y2 = list(f["good_T2_y2"].array(library="pd")[0]);
good_z1 = list(f["good_T2_z1"].array(library="pd")[0]);
good_z2 = list(f["good_T2_z2"].array(library="pd")[0]);

# %%
mds = []
for (x1_, x2_, y1_, y2_, z1_, z2_) in zip(x1, x2, y1, y2, z1, z2):
    mds.append((x1_, y1_, z1_))
    mds.append((x2_, y2_, z2_))
mds = list(set(mds))

# %%
sgs = []
for (x1_, x2_, y1_, y2_, z1_, z2_) in zip(x1, x2, y1, y2, z1, z2):
    sgs.append(((x1_, x2_), (y1_, y2_), (z1_, z2_)))

# %%
print(len(mds))
print(len(sgs))
# Out:
# 16661
# 39029

# %%
good_mds = []
for (x1_, x2_, y1_, y2_, z1_, z2_) in zip(good_x1, good_x2, good_y1, good_y2, good_z1, good_z2):
    good_mds.append((x1_, y1_, z1_))
    good_mds.append((x2_, y2_, z2_))
good_mds = list(set(good_mds))

# %%
good_sgs = []
for (x1_, x2_, y1_, y2_, z1_, z2_) in zip(good_x1, good_x2, good_y1, good_y2, good_z1, good_z2):
    good_sgs.append(((x1_, x2_), (y1_, y2_), (z1_, z2_)))
good_sgs = list(set(good_sgs))

# %%
print(len(good_mds))
print(len(good_sgs))
# Out:
# 2440
# 1916

# %%
sgcolor = "rgb(151,149,1)"
sgopacity = 0.2
sgcolor = "rgb(125,125,125)"
sgopacity = 0.5
goodsgcolor = "yellow"
goodsgopacity = 0.45
mdcolor = "cyan"
mdopacity = 0.2
simcolor = "red"
simopacity = 1
simrecocolor = "blue"
simrecoopacity = 1
size = 800
sim_denom_cut = 6 # Hard Scatter Only
sg2dcolor = "rgb(125,125,125)"
sg2dopacity = 0.5
goodsg2dcolor = "yellow"
goodsg2dopacity = 0.95

# %%
md_xs = [md[0] for md in mds]
md_ys = [md[1] for md in mds]
md_zs = [md[2] for md in mds]
md_idx = [i for i in enumerate(mds)]

# %%
mds_to_draw = go.Scatter3d(x=md_zs,
                           y=md_ys,
                           z=md_xs,
                           mode="markers",
                           marker=dict(
                               symbol='circle',
                               size=0.5,
                               color=mdcolor,
                               colorscale='Viridis',
                               opacity=mdopacity,
                               ),
                           text=md_idx,
                           hoverinfo='text',
                          )
mds_to_draw_only = go.Scatter3d(x=md_zs,
                           y=md_ys,
                           z=md_xs,
                           mode="markers",
                           marker=dict(
                               symbol='circle',
                               size=1.5,
                               color=mdcolor,
                               colorscale='Viridis',
                               opacity=mdopacity,
                               ),
                           text=md_idx,
                           hoverinfo='text',
                          )

# %%
Xsg = []
Ysg = []
Zsg = []
for sg in sgs:
    Xsg += [sg[0][0], sg[0][1], None] # None is to disconnect the lines
    Ysg += [sg[1][0], sg[1][1], None] # None is to disconnect the lines
    Zsg += [sg[2][0], sg[2][1], None] # None is to disconnect the lines

# %%
sgs_to_draw = go.Scatter3d(
        x = Zsg,
        y = Ysg,
        z = Xsg,
        mode='lines',
        line=dict(
            color=sgcolor,
            width=0.5,
        ),
        opacity=sgopacity,
        hoverinfo='none',
)

# %%
good_md_xs = [md[0] for md in good_mds]
good_md_ys = [md[1] for md in good_mds]
good_md_zs = [md[2] for md in good_mds]
good_md_idx = [i for i in enumerate(good_mds)]

# %%
good_mds_to_draw = go.Scatter3d(x=good_md_zs,
                                y=good_md_ys,
                                z=good_md_xs,
                                mode="markers",
                                marker=dict(
                                    symbol='circle',
                                    size=1,
                                    color=mdcolor,
                                    colorscale='Viridis',
                                    opacity=mdopacity,
                                    ),
                                text=good_md_idx,
                                hoverinfo='text',
                               )

# %%
good_Xsg = []
good_Ysg = []
good_Zsg = []
for good_sg in good_sgs:
    good_Xsg += [good_sg[0][0], good_sg[0][1], None] # None is to disconnect the lines
    good_Ysg += [good_sg[1][0], good_sg[1][1], None] # None is to disconnect the lines
    good_Zsg += [good_sg[2][0], good_sg[2][1], None] # None is to disconnect the lines

# %%
Xsim = []
Ysim = []
Zsim = []
nsim = 0
for itrk, (pt, eta, phi, vx, vy, vz, q, denom) in enumerate(zip(sim_pt, sim_eta, sim_phi, sim_vx, sim_vy, sim_vz, sim_q, sim_denom)):
    if pt < 1.2 or abs(eta) > 2.4:
        continue
    if denom < sim_denom_cut:
        continue
    nsim += 1
    points = m.get_helix_points(m.construct_helix_from_kinematics(pt, eta, phi, vx, vy, vz, q))
    Xsim += list(points[0]) + [None] # Non is to disconnec the lines
    Ysim += list(points[1]) + [None] # Non is to disconnec the lines
    Zsim += list(points[2]) + [None] # Non is to disconnec the lines

# %%
Xsim_reco = []
Ysim_reco = []
Zsim_reco = []
nsim_reco = 0
for itrk, (pt, eta, phi, vx, vy, vz, q, denom, matched) in enumerate(zip(sim_pt, sim_eta, sim_phi, sim_vx, sim_vy, sim_vz, sim_q, sim_denom, sim_TC_matched)):
    if pt < 1.2 or abs(eta) > 2.4:
        continue
    if denom < sim_denom_cut:
        continue
    if not matched:
        continue
    nsim_reco += 1
    points = m.get_helix_points(m.construct_helix_from_kinematics(pt, eta, phi, vx, vy, vz, q))
    Xsim_reco += list(points[0]) + [None] # Non is to disconnec the lines
    Ysim_reco += list(points[1]) + [None] # Non is to disconnec the lines
    Zsim_reco += list(points[2]) + [None] # Non is to disconnec the lines

# %%
print(nsim)
print(nsim_reco)
# Out:
# 455
# 393

# %%
sims_to_draw = go.Scatter3d(
        x = Zsim,
        y = Ysim,
        z = Xsim,
        mode='lines',
        line=dict(
            color=simcolor,
            width=2,
        ),
        opacity=simopacity,
        hoverinfo='none',
)

# %%
sims_recoed_to_draw = go.Scatter3d(
        x = Zsim_reco,
        y = Ysim_reco,
        z = Xsim_reco,
        mode='lines',
        line=dict(
            color=simrecocolor,
            width=2,
        ),
        opacity=simrecoopacity,
        hoverinfo='none',
)

# %%
fig = go.Figure([sims_to_draw, sims_to_draw])

# %%
fig.update_layout(
    template="plotly_dark",
    paper_bgcolor="rgb(0,0,0,1)",
    scene = dict(
        xaxis = dict(nticks=10, range=[-300,300],),
        yaxis = dict(nticks=10, range=[-200,200],),
        zaxis = dict(nticks=10, range=[-200,200],),
        aspectratio=dict(x=1, y=0.666, z=0.666),
    ),
    width=size,
    height=size,
    margin=dict(r=20, l=10, b=10, t=10));

# %%
fig.write_html("sims_all.html")

# %%
fig = go.Figure([sims_to_draw, sims_recoed_to_draw])

# %%
fig.update_layout(
    template="plotly_dark",
    paper_bgcolor="rgb(0,0,0,1)",
    scene = dict(
        xaxis = dict(nticks=10, range=[-300,300],),
        yaxis = dict(nticks=10, range=[-200,200],),
        zaxis = dict(nticks=10, range=[-200,200],),
        aspectratio=dict(x=1, y=0.666, z=0.666),
    ),
    width=size,
    height=size,
    margin=dict(r=20, l=10, b=10, t=10));

# %%
fig.write_html("sims_recoed.html")

# %%
good_sgs_to_draw = go.Scatter3d(
        x = good_Zsg,
        y = good_Ysg,
        z = good_Xsg,
        mode='lines',
        line=dict(
            color=goodsgcolor,
            width=2,
        ),
        opacity=goodsgopacity,
        hoverinfo='none',
)

# %%
fig = go.Figure([mds_to_draw, mds_to_draw_only])

# %%
fig.update_layout(
    template="plotly_dark",
    paper_bgcolor="rgb(0,0,0,1)",
    scene = dict(
        xaxis = dict(nticks=10, range=[-300,300],),
        yaxis = dict(nticks=10, range=[-200,200],),
        zaxis = dict(nticks=10, range=[-200,200],),
        aspectratio=dict(x=1, y=0.666, z=0.666),
    ),
    width=size,
    height=size,
    margin=dict(r=20, l=10, b=10, t=10));

# %%
fig.write_html("nodes_all.html")

# %%
fig = go.Figure([sgs_to_draw, mds_to_draw])

# %%
fig.update_layout(
    template="plotly_dark",
    paper_bgcolor="rgb(0,0,0,1)",
    scene = dict(
        xaxis = dict(nticks=10, range=[-300,300],),
        yaxis = dict(nticks=10, range=[-200,200],),
        zaxis = dict(nticks=10, range=[-200,200],),
        aspectratio=dict(x=1, y=0.666, z=0.666),
    ),
    width=size,
    height=size,
    margin=dict(r=20, l=10, b=10, t=10));

# %%
fig.write_html("graph_all.html")

# %%
fig = go.Figure([sgs_to_draw, mds_to_draw, good_sgs_to_draw])

# %%
fig.update_layout(
    template="plotly_dark",
    paper_bgcolor="rgb(0,0,0,1)",
    scene = dict(
        xaxis = dict(nticks=10, range=[-300,300],),
        yaxis = dict(nticks=10, range=[-200,200],),
        zaxis = dict(nticks=10, range=[-200,200],),
        aspectratio=dict(x=1, y=0.666, z=0.666),
    ),
    width=size,
    height=size,
    margin=dict(r=20, l=10, b=10, t=10));

# %%
fig.write_html("graph_good.html")

# %%
fig = go.Figure([good_sgs_to_draw, good_mds_to_draw, sims_to_draw, sims_recoed_to_draw])

# %%
fig.update_layout(
    template="plotly_dark",
    paper_bgcolor="rgb(0,0,0,1)",
    scene = dict(
        xaxis = dict(nticks=10, range=[-300,300],),
        yaxis = dict(nticks=10, range=[-200,200],),
        zaxis = dict(nticks=10, range=[-200,200],),
        aspectratio=dict(x=1, y=0.666, z=0.666),
    ),
    width=size,
    height=size,
    margin=dict(r=20, l=10, b=10, t=10));

# %%
fig.write_html("graph_good_and_sim.html")

# %%
fig = go.Figure([sims_to_draw, sims_recoed_to_draw])

# %%
fig.update_layout(
    template="plotly_dark",
    paper_bgcolor="rgb(0,0,0,1)",
    scene = dict(
        xaxis = dict(nticks=10, range=[-300,300],),
        yaxis = dict(nticks=10, range=[-200,200],),
        zaxis = dict(nticks=10, range=[-200,200],),
        aspectratio=dict(x=1, y=0.666, z=0.666),
    ),
    width=size,
    height=size,
    margin=dict(r=20, l=10, b=10, t=10));

# %%
fig.write_html("sims_all_and_recoed.html")

# %%
zcut=120

md_xs_2d = []
md_ys_2d = []
md_zs_2d = []
md_idx_2d = []
for idx, md in enumerate(mds):
    if abs(md[2]) > zcut:
        continue
    md_xs_2d.append(md[0])
    md_ys_2d.append(md[1])
    md_zs_2d.append(md[2])
    md_idx_2d.append(idx)

Xsg_2d = []
Ysg_2d = []
Zsg_2d = []
for sg in sgs:
    if abs(sg[2][0]) > zcut or abs(sg[2][1]) > zcut:
        continue
    Xsg_2d += [sg[0][0], sg[0][1], None] # None is to disconnect the lines
    Ysg_2d += [sg[1][0], sg[1][1], None] # None is to disconnect the lines
    Zsg_2d += [sg[2][0], sg[2][1], None] # None is to disconnect the lines

good_md_xs_2d = []
good_md_ys_2d = []
good_md_zs_2d = []
good_md_idx_2d = []
for idx, md in enumerate(good_mds):
    if abs(md[2]) > zcut:
        continue
    good_md_xs_2d.append(md[0])
    good_md_ys_2d.append(md[1])
    good_md_zs_2d.append(md[2])
    good_md_idx_2d.append(idx)

good_Xsg_2d = []
good_Ysg_2d = []
good_Zsg_2d = []
for sg in good_sgs:
    if abs(sg[2][0]) > zcut or abs(sg[2][1]) > zcut:
        continue
    good_Xsg_2d += [sg[0][0], sg[0][1], None] # None is to disconnect the lines
    good_Ysg_2d += [sg[1][0], sg[1][1], None] # None is to disconnect the lines
    good_Zsg_2d += [sg[2][0], sg[2][1], None] # None is to disconnect the lines

# %%
foraxis = go.Scatter(
        x = Xsim,
        y = Ysim,
        mode='lines',
        line=dict(
            color=simcolor,
            width=0.,
        ),
        opacity=0,
        hoverinfo='none',
)
sim_to_draw_2d = go.Scatter(
        x = Xsim,
        y = Ysim,
        mode='lines',
        line=dict(
            color=simcolor,
            width=0.5,
        ),
        opacity=simopacity,
        hoverinfo='none',
)
sim_recoed_to_draw_2d = go.Scatter(
        x = Xsim_reco,
        y = Ysim_reco,
        mode='lines',
        line=dict(
            color=simrecocolor,
            width=0.5,
        ),
        opacity=simrecoopacity,
        hoverinfo='none',
)

# %%
mds_to_draw_2d = go.Scatter(x=md_xs_2d,
                            y=md_ys_2d,
                            mode="markers",
                            marker=dict(
                                symbol='circle',
                                size=1.5,
                                color=mdcolor,
                                colorscale='Viridis',
                                opacity=mdopacity,
                                ),
                            text=md_idx_2d,
                            hoverinfo='text',
                           )
sgs_to_draw_2d = go.Scatter(
        x = Ysg_2d,
        y = Xsg_2d,
        mode='lines',
        line=dict(
            color=sg2dcolor,
            width=0.2,
        ),
        opacity=sg2dopacity,
        hoverinfo='none',
)

# %%
fig = go.Figure([mds_to_draw_2d, mds_to_draw_2d])

# %%
fig.update_layout(
    template="plotly_dark",
    paper_bgcolor="rgb(0,0,0,1)",
    xaxis_range=[-130,130],
    yaxis_range=[-150,150],
    width=size,
    height=size,
    margin=dict(r=20, l=10, b=10, t=10));

# %%
fig.write_html("nodes_all_2d.html")

# %%
fig = go.Figure([foraxis, mds_to_draw_2d, sgs_to_draw_2d])

# %%
fig.update_layout(
    template="plotly_dark",
    paper_bgcolor="rgb(0,0,0,1)",
    xaxis_range=[-130,130],
    yaxis_range=[-150,150],
    width=size,
    height=size,
    margin=dict(r=20, l=10, b=10, t=10));

# %%
fig.write_html("graph_all_2d.html")

# %%
good_mds_to_draw_2d = go.Scatter(x=good_md_xs_2d,
                                 y=good_md_ys_2d,
                                 mode="markers",
                                 marker=dict(
                                     symbol='circle',
                                     size=1.5,
                                     color=mdcolor,
                                     colorscale='Viridis',
                                     opacity=mdopacity,
                                     ),
                                 text=md_idx_2d,
                                 hoverinfo='text',
                                )
good_sgs_to_draw_2d = go.Scatter(
        x = good_Ysg_2d,
        y = good_Xsg_2d,
        mode='lines',
        line=dict(
            color=goodsg2dcolor,
            width=0.5,
        ),
        opacity=goodsg2dopacity,
        hoverinfo='none',
)

# %%
fig = go.Figure([mds_to_draw_2d, sgs_to_draw_2d, good_sgs_to_draw_2d])

# %%
fig.update_layout(
    template="plotly_dark",
    paper_bgcolor="rgb(0,0,0,1)",
    xaxis_range=[-130,130],
    yaxis_range=[-150,150],
    width=size,
    height=size,
    margin=dict(r=20, l=10, b=10, t=10));

# %%
fig.write_html("graph_good_2d.html")

# %%
Xsim = []
Ysim = []
Zsim = []
nsim = 0
for itrk, (pt, eta, phi, vx, vy, vz, q, denom) in enumerate(zip(sim_pt, sim_eta, sim_phi, sim_vx, sim_vy, sim_vz, sim_q, sim_denom)):
    if pt < 1.2 or abs(eta) > 0.8:
        continue
    if denom < sim_denom_cut:
        continue
    nsim += 1
    points = m.get_helix_points(m.construct_helix_from_kinematics(pt, eta, phi, vx, vy, vz, q))
    Xsim += list(points[0]) + [None] # Non is to disconnec the lines
    Ysim += list(points[1]) + [None] # Non is to disconnec the lines
    Zsim += list(points[2]) + [None] # Non is to disconnec the lines
Xsim_reco = []
Ysim_reco = []
Zsim_reco = []
nsim_reco = 0
for itrk, (pt, eta, phi, vx, vy, vz, q, denom, matched) in enumerate(zip(sim_pt, sim_eta, sim_phi, sim_vx, sim_vy, sim_vz, sim_q, sim_denom, sim_TC_matched)):
    if pt < 1.2 or abs(eta) > 0.8:
        continue
    if denom < sim_denom_cut:
        continue
    if not matched:
        continue
    nsim_reco += 1
    points = m.get_helix_points(m.construct_helix_from_kinematics(pt, eta, phi, vx, vy, vz, q))
    Xsim_reco += list(points[0]) + [None] # Non is to disconnec the lines
    Ysim_reco += list(points[1]) + [None] # Non is to disconnec the lines
    Zsim_reco += list(points[2]) + [None] # Non is to disconnec the lines
print(nsim)
print(nsim_reco)
# Out:
# 158
# 143

# %%
fig = go.Figure([sim_to_draw_2d,sim_to_draw_2d])

# %%
fig.update_layout(
    template="plotly_dark",
    paper_bgcolor="rgb(0,0,0,1)",
    xaxis_range=[-130,130],
    yaxis_range=[-150,150],
    width=size,
    height=size,
    margin=dict(r=20, l=10, b=10, t=10));

# %%
fig.write_html("sim_all_2d.html")

# %%
fig = go.Figure([sim_to_draw_2d, sim_recoed_to_draw_2d])

# %%
fig.update_layout(
    template="plotly_dark",
    paper_bgcolor="rgb(0,0,0,1)",
    xaxis_range=[-130,130],
    yaxis_range=[-150,150],
    width=size,
    height=size,
    margin=dict(r=20, l=10, b=10, t=10));

# %%
fig.write_html("sim_all_and_recoed_2d.html")

# %%
fig = go.Figure([sim_to_draw_2d, sim_recoed_to_draw_2d, good_sgs_to_draw_2d])

# %%
fig.update_layout(
    template="plotly_dark",
    paper_bgcolor="rgb(0,0,0,1)",
    xaxis_range=[-130,130],
    yaxis_range=[-150,150],
    width=size,
    height=size,
    margin=dict(r=20, l=10, b=10, t=10));

# %%
fig.write_html("sim_all_and_recoed_and_graph_good_2d.html")
